# %%
# %pip install bpy kaggle
# Out:
# Requirement already satisfied: bpy in c:\users\alex_\documents\tfg\.venv\lib\site-packages (4.2.0)
# Collecting kaggle
#   Downloading kaggle-1.6.17.tar.gz (82 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cython in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from bpy) (3.0.11)
# Requirement already satisfied: numpy in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from bpy) (2.1.2)
# Requirement already satisfied: requests in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from bpy) (2.32.3)
# Requirement already satisfied: zstandard in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from bpy) (0.23.0)
# Requirement already satisfied: six>=1.10 in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3 in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from kaggle) (2.2.3)
# Collecting bleach (from kaggle)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting webencodings (from bleach->kaggle)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from requests->bpy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from requests->bpy) (3.10)
# Requirement already satisfied: colorama in c:\users\alex_\documents\tfg\.venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105798 sha256=035273ded9c0f7b64d09cd9f36f908786fac88ddfd2550bf7cb850d5d9a46a91
#   Stored in directory: c:\users\alex_\appdata\local\pip\cache\wheels\ff\55\fb\b27a466be754d2a06ffe0e37b248d844f090a63b51becea85d
# Successfully built kaggle
# Installing collected packages: webencodings, text-unidecode, tqdm, python-slugify, bleach, kaggle
# Successfully installed bleach-6.1.0 kaggle-1.6.17 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.66.5 webencodings-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import bpy
import os
import json

# %%
# Load Kaggle API credentials
with open('../kaggle.json') as f:
    kaggle_creds = json.load(f)

# %%
os.environ['KAGGLE_USERNAME'] = kaggle_creds['username']
os.environ['KAGGLE_KEY'] = kaggle_creds['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

api.dataset_download_cli(
    'alk222/raw-mixamo-animations', path='./dataset', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alk222/raw-mixamo-animations
# License(s): unknown
# Downloading raw-mixamo-animations.zip to ./dataset
# 100%|██████████| 54.7M/54.7M [00:02<00:00, 22.0MB/s]

# %%
path = "./dataset"

# %%
subfolders = [f.path for f in os.scandir(path) if f.is_dir()]

# %%
for subfolder in subfolders:
    files = os.listdir(subfolder)
    for f in files:
        if f.endswith('.fbx') :
            print("Proccessing file: " + f)
            mesh_file = os.path.join(subfolder, f)
            obj_file = os.path.splitext(mesh_file)[0] + ".obj"

            bpy.ops.object.select_all(action='SELECT')
            bpy.ops.object.delete()

            bpy.ops.import_scene.fbx(filepath=mesh_file) # change this line

            bpy.ops.object.select_all(action='SELECT')

            bpy.ops.wm.obj_export(filepath=obj_file)
# Out:
# Proccessing file: dance (1).fbx
# FBX version: 7700
# Proccessing file: dance (10).fbx
# FBX version: 7700
# Proccessing file: dance (11).fbx
# FBX version: 7700
# Proccessing file: dance (12).fbx
# FBX version: 7700
# Proccessing file: dance (13).fbx
# FBX version: 7700
# Proccessing file: dance (14).fbx
# FBX version: 7700
# Proccessing file: dance (15).fbx
# FBX version: 7700
# Proccessing file: dance (16).fbx
# FBX version: 7700
# Proccessing file: dance (17).fbx
# FBX version: 7700
# Proccessing file: dance (18).fbx
# FBX version: 7700
# Proccessing file: dance (19).fbx
# FBX version: 7700
# Proccessing file: dance (2).fbx
# FBX version: 7700
# Proccessing file: dance (20).fbx
# FBX version: 7700
# Proccessing file: dance (21).fbx
# FBX version: 7700
# Proccessing file: dance (22).fbx
# FBX version: 7700
# Proccessing file: dance (23).fbx
# FBX version: 7700
# Proccessing file: dance (24).fbx
# FBX version: 7700
# Proccessing file: dance (25).fbx
# FBX version: 7700
# Proccessing file: dance (26).fbx
# FBX version: 7700
# Proccessing file: dance (27).fbx
# FBX version: 7700
# Proccessing file: dance (28).fbx
# FBX version: 7700
# Proccessing file: dance (29).fbx
# FBX version: 7700
# Proccessing file: dance (3).fbx
# FBX version: 7700
# Proccessing file: dance (30).fbx
# FBX version: 7700
# Proccessing file: dance (31).fbx
# FBX version: 7700
# Proccessing file: dance (32).fbx
# FBX version: 7700
# Proccessing file: dance (33).fbx
# FBX version: 7700
# Proccessing file: dance (34).fbx
# FBX version: 7700
# Proccessing file: dance (35).fbx
# FBX version: 7700
# Proccessing file: dance (36).fbx
# FBX version: 7700
# Proccessing file: dance (37).fbx
# FBX version: 7700
# Proccessing file: dance (38).fbx
# FBX version: 7700
# Proccessing file: dance (39).fbx
# FBX version: 7700
# Proccessing file: dance (4).fbx
# FBX version: 7700
# Proccessing file: dance (40).fbx
# FBX version: 7700
# Proccessing file: dance (41).fbx
# FBX version: 7700
# Proccessing file: dance (42).fbx
# FBX version: 7700
# Proccessing file: dance (43).fbx
# FBX version: 7700
# Proccessing file: dance (44).fbx
# FBX version: 7700
# Proccessing file: dance (45).fbx
# FBX version: 7700
# Proccessing file: dance (46).fbx
# FBX version: 7700
# Proccessing file: dance (47).fbx
# FBX version: 7700
# Proccessing file: dance (48).fbx
# FBX version: 7700
# Proccessing file: dance (49).fbx
# FBX version: 7700
# Proccessing file: dance (5).fbx
# FBX version: 7700
# Proccessing file: dance (50).fbx
# FBX version: 7700
# Proccessing file: dance (51).fbx
# FBX version: 7700
# Proccessing file: dance (52).fbx
# FBX version: 7700
# Proccessing file: dance (53).fbx
# FBX version: 7700
# Proccessing file: dance (54).fbx
# FBX version: 7700
# Proccessing file: dance (55).fbx
# FBX version: 7700
# Proccessing file: dance (56).fbx
# FBX version: 7700
# Proccessing file: dance (57).fbx
# FBX version: 7700
# Proccessing file: dance (58).fbx
# FBX version: 7700
# Proccessing file: dance (59).fbx
# FBX version: 7700
# Proccessing file: dance (6).fbx
# FBX version: 7700
# Proccessing file: dance (60).fbx
# FBX version: 7700
# Proccessing file: dance (61).fbx
# FBX version: 7700
# Proccessing file: dance (62).fbx
# FBX version: 7700
# Proccessing file: dance (63).fbx
# FBX version: 7700
# Proccessing file: dance (64).fbx
# FBX version: 7700
# Proccessing file: dance (65).fbx
# FBX version: 7700
# Proccessing file: dance (66).fbx
# FBX version: 7700
# Proccessing file: dance (67).fbx
# FBX version: 7700
# Proccessing file: dance (68).fbx
# FBX version: 7700
# Proccessing file: dance (69).fbx
# FBX version: 7700
# Proccessing file: dance (7).fbx
# FBX version: 7700
# Proccessing file: dance (70).fbx
# FBX version: 7700
# Proccessing file: dance (71).fbx
# FBX version: 7700
# Proccessing file: dance (72).fbx
# FBX version: 7700
# Proccessing file: dance (73).fbx
# FBX version: 7700
# Proccessing file: dance (74).fbx
# FBX version: 7700
# Proccessing file: dance (75).fbx
# FBX version: 7700
# Proccessing file: dance (76).fbx
# FBX version: 7700
# Proccessing file: dance (77).fbx
# FBX version: 7700
# Proccessing file: dance (78).fbx
# FBX version: 7700
# Proccessing file: dance (79).fbx
# FBX version: 7700
# Proccessing file: dance (8).fbx
# FBX version: 7700
# Proccessing file: dance (80).fbx
# FBX version: 7700
# Proccessing file: dance (81).fbx
# FBX version: 7700
# Proccessing file: dance (82).fbx
# FBX version: 7700
# Proccessing file: dance (83).fbx
# FBX version: 7700
# Proccessing file: dance (84).fbx
# FBX version: 7700
# Proccessing file: dance (85).fbx
# FBX version: 7700
# Proccessing file: dance (86).fbx
# FBX version: 7700
# Proccessing file: dance (87).fbx
# FBX version: 7700
# Proccessing file: dance (88).fbx
# FBX version: 7700
# Proccessing file: dance (89).fbx
# FBX version: 7700
# Proccessing file: dance (9).fbx
# FBX version: 7700
# Proccessing file: dance (90).fbx
# FBX version: 7700
# Proccessing file: dance (91).fbx
# FBX version: 7700
# Proccessing file: dance (92).fbx
# FBX version: 7700
# Proccessing file: dance (93).fbx
# FBX version: 7700
# Proccessing file: dance (94).fbx
# FBX version: 7700
# Proccessing file: fight (1).fbx
# FBX version: 7700
# Proccessing file: fight (10).fbx
# FBX version: 7700
# Proccessing file: fight (11).fbx
# FBX version: 7700
# Proccessing file: fight (12).fbx
# FBX version: 7700
# Proccessing file: fight (13).fbx
# FBX version: 7700
# Proccessing file: fight (14).fbx
# FBX version: 7700
# Proccessing file: fight (15).fbx
# FBX version: 7700
# Proccessing file: fight (16).fbx
# FBX version: 7700
# Proccessing file: fight (17).fbx
# FBX version: 7700
# Proccessing file: fight (18).fbx
# FBX version: 7700
# Proccessing file: fight (19).fbx
# FBX version: 7700
# Proccessing file: fight (2).fbx
# FBX version: 7700
# Proccessing file: fight (20).fbx
# FBX version: 7700
# Proccessing file: fight (21).fbx
# FBX version: 7700
# Proccessing file: fight (22).fbx
# FBX version: 7700
# Proccessing file: fight (23).fbx
# FBX version: 7700
# Proccessing file: fight (24).fbx
# FBX version: 7700
# Proccessing file: fight (25).fbx
# FBX version: 7700
# Proccessing file: fight (26).fbx
# FBX version: 7700
# Proccessing file: fight (27).fbx
# FBX version: 7700
# Proccessing file: fight (28).fbx
# FBX version: 7700
# Proccessing file: fight (29).fbx
# FBX version: 7700
# Proccessing file: fight (3).fbx
# FBX version: 7700
# Proccessing file: fight (30).fbx
# FBX version: 7700
# Proccessing file: fight (31).fbx
# FBX version: 7700
# Proccessing file: fight (32).fbx
# FBX version: 7700
# Proccessing file: fight (33).fbx
# FBX version: 7700
# Proccessing file: fight (34).fbx
# FBX version: 7700
# Proccessing file: fight (35).fbx
# FBX version: 7700
# Proccessing file: fight (36).fbx
# FBX version: 7700
# Proccessing file: fight (37).fbx
# FBX version: 7700
# Proccessing file: fight (38).fbx
# FBX version: 7700
# Proccessing file: fight (39).fbx
# FBX version: 7700
# Proccessing file: fight (4).fbx
# FBX version: 7700
# Proccessing file: fight (40).fbx
# FBX version: 7700
# Proccessing file: fight (41).fbx
# FBX version: 7700
# Proccessing file: fight (42).fbx
# FBX version: 7700
# Proccessing file: fight (43).fbx
# FBX version: 7700
# Proccessing file: fight (44).fbx
# FBX version: 7700
# Proccessing file: fight (45).fbx
# FBX version: 7700
# Proccessing file: fight (46).fbx
# FBX version: 7700
# Proccessing file: fight (47).fbx
# FBX version: 7700
# Proccessing file: fight (48).fbx
# FBX version: 7700
# Proccessing file: fight (49).fbx
# FBX version: 7700
# Proccessing file: fight (5).fbx
# FBX version: 7700
# Proccessing file: fight (50).fbx
# FBX version: 7700
# Proccessing file: fight (51).fbx
# FBX version: 7700
# Proccessing file: fight (52).fbx
# FBX version: 7700
# Proccessing file: fight (53).fbx
# FBX version: 7700
# Proccessing file: fight (54).fbx
# FBX version: 7700
# Proccessing file: fight (55).fbx
# FBX version: 7700
# Proccessing file: fight (56).fbx
# FBX version: 7700
# Proccessing file: fight (57).fbx
# FBX version: 7700
# Proccessing file: fight (58).fbx
# FBX version: 7700
# Proccessing file: fight (59).fbx
# FBX version: 7700
# Proccessing file: fight (6).fbx
# FBX version: 7700
# Proccessing file: fight (60).fbx
# FBX version: 7700
# Proccessing file: fight (61).fbx
# FBX version: 7700
# Proccessing file: fight (62).fbx
# FBX version: 7700
# Proccessing file: fight (63).fbx
# FBX version: 7700
# Proccessing file: fight (64).fbx
# FBX version: 7700
# Proccessing file: fight (65).fbx
# FBX version: 7700
# Proccessing file: fight (66).fbx
# FBX version: 7700
# Proccessing file: fight (67).fbx
# FBX version: 7700
# Proccessing file: fight (68).fbx
# FBX version: 7700
# Proccessing file: fight (69).fbx
# FBX version: 7700
# Proccessing file: fight (7).fbx
# FBX version: 7700
# Proccessing file: fight (70).fbx
# FBX version: 7700
# Proccessing file: fight (71).fbx
# FBX version: 7700
# Proccessing file: fight (72).fbx
# FBX version: 7700
# Proccessing file: fight (73).fbx
# FBX version: 7700
# Proccessing file: fight (74).fbx
# FBX version: 7700
# Proccessing file: fight (75).fbx
# FBX version: 7700
# Proccessing file: fight (76).fbx
# FBX version: 7700
# Proccessing file: fight (77).fbx
# FBX version: 7700
# Proccessing file: fight (78).fbx
# FBX version: 7700
# Proccessing file: fight (79).fbx
# FBX version: 7700
# Proccessing file: fight (8).fbx
# FBX version: 7700
# Proccessing file: fight (80).fbx
# FBX version: 7700
# Proccessing file: fight (81).fbx
# FBX version: 7700
# Proccessing file: fight (82).fbx
# FBX version: 7700
# Proccessing file: fight (83).fbx
# FBX version: 7700
# Proccessing file: fight (84).fbx
# FBX version: 7700
# Proccessing file: fight (85).fbx
# FBX version: 7700
# Proccessing file: fight (86).fbx
# FBX version: 7700
# Proccessing file: fight (87).fbx
# FBX version: 7700
# Proccessing file: fight (88).fbx
# FBX version: 7700
# Proccessing file: fight (89).fbx
# FBX version: 7700
# Proccessing file: fight (9).fbx
# FBX version: 7700
# Proccessing file: fight (90).fbx
# FBX version: 7700
# Proccessing file: fight (91).fbx
# FBX version: 7700
# Proccessing file: fight (92).fbx
# FBX version: 7700
# Proccessing file: fight (93).fbx
# FBX version: 7700
# Proccessing file: greeting (1).fbx
# FBX version: 7700
# Proccessing file: greeting (2).fbx
# FBX version: 7700
# Proccessing file: greeting (3).fbx
# FBX version: 7700
# Proccessing file: greeting (4).fbx
# FBX version: 7700
# Proccessing file: greeting (5).fbx
# FBX version: 7700
# Proccessing file: greeting (6).fbx
# FBX version: 7700
# Proccessing file: point_out (1).fbx
# FBX version: 7700
# Proccessing file: point_out (10).fbx
# FBX version: 7700
# Proccessing file: point_out (11).fbx
# FBX version: 7700
# Proccessing file: point_out (2).fbx
# FBX version: 7700
# Proccessing file: point_out (3).fbx
# FBX version: 7700
# Proccessing file: point_out (4).fbx
# FBX version: 7700
# Proccessing file: point_out (5).fbx
# FBX version: 7700
# Proccessing file: point_out (6).fbx
# FBX version: 7700
# Proccessing file: point_out (7).fbx
# FBX version: 7700
# Proccessing file: point_out (8).fbx
# FBX version: 7700
# Proccessing file: point_out (9).fbx
# FBX version: 7700
# Proccessing file: run (1).fbx
# FBX version: 7700
# Proccessing file: run (10).fbx
# FBX version: 7700
# Proccessing file: run (11).fbx
# FBX version: 7700
# Proccessing file: run (12).fbx
# FBX version: 7700
# Proccessing file: run (13).fbx
# FBX version: 7700
# Proccessing file: run (14).fbx
# FBX version: 7700
# Proccessing file: run (15).fbx
# FBX version: 7700
# Proccessing file: run (16).fbx
# FBX version: 7700
# Proccessing file: run (17).fbx
# FBX version: 7700
# Proccessing file: run (18).fbx
# FBX version: 7700
# Proccessing file: run (19).fbx
# FBX version: 7700
# Proccessing file: run (2).fbx
# FBX version: 7700
# Proccessing file: run (20).fbx
# FBX version: 7700
# Proccessing file: run (21).fbx
# FBX version: 7700
# Proccessing file: run (22).fbx
# FBX version: 7700
# Proccessing file: run (23).fbx
# FBX version: 7700
# Proccessing file: run (24).fbx
# FBX version: 7700
# Proccessing file: run (25).fbx
# FBX version: 7700
# Proccessing file: run (26).fbx
# FBX version: 7700
# Proccessing file: run (27).fbx
# FBX version: 7700
# Proccessing file: run (28).fbx
# FBX version: 7700
# Proccessing file: run (29).fbx
# FBX version: 7700
# Proccessing file: run (3).fbx
# FBX version: 7700
# Proccessing file: run (30).fbx
# FBX version: 7700
# Proccessing file: run (31).fbx
# FBX version: 7700
# Proccessing file: run (32).fbx
# FBX version: 7700
# Proccessing file: run (33).fbx
# FBX version: 7700
# Proccessing file: run (34).fbx
# FBX version: 7700
# Proccessing file: run (35).fbx
# FBX version: 7700
# Proccessing file: run (36).fbx
# FBX version: 7700
# Proccessing file: run (37).fbx
# FBX version: 7700
# Proccessing file: run (38).fbx
# FBX version: 7700
# Proccessing file: run (39).fbx
# FBX version: 7700
# Proccessing file: run (4).fbx
# FBX version: 7700
# Proccessing file: run (40).fbx
# FBX version: 7700
# Proccessing file: run (41).fbx
# FBX version: 7700
# Proccessing file: run (42).fbx
# FBX version: 7700
# Proccessing file: run (43).fbx
# FBX version: 7700
# Proccessing file: run (44).fbx
# FBX version: 7700
# Proccessing file: run (45).fbx
# FBX version: 7700
# Proccessing file: run (46).fbx
# FBX version: 7700
# Proccessing file: run (47).fbx
# FBX version: 7700
# Proccessing file: run (48).fbx
# FBX version: 7700
# Proccessing file: run (49).fbx
# FBX version: 7700
# Proccessing file: run (5).fbx
# FBX version: 7700
# Proccessing file: run (50).fbx
# FBX version: 7700
# Proccessing file: run (51).fbx
# FBX version: 7700
# Proccessing file: run (52).fbx
# FBX version: 7700
# Proccessing file: run (53).fbx
# FBX version: 7700
# Proccessing file: run (54).fbx
# FBX version: 7700
# Proccessing file: run (55).fbx
# FBX version: 7700
# Proccessing file: run (56).fbx
# FBX version: 7700
# Proccessing file: run (57).fbx
# FBX version: 7700
# Proccessing file: run (58).fbx
# FBX version: 7700
# Proccessing file: run (59).fbx
# FBX version: 7700
# Proccessing file: run (6).fbx
# FBX version: 7700
# Proccessing file: run (60).fbx
# FBX version: 7700
# Proccessing file: run (61).fbx
# FBX version: 7700
# Proccessing file: run (62).fbx
# FBX version: 7700
# Proccessing file: run (63).fbx
# FBX version: 7700
# Proccessing file: run (64).fbx
# FBX version: 7700
# Proccessing file: run (65).fbx
# FBX version: 7700
# Proccessing file: run (66).fbx
# FBX version: 7700
# Proccessing file: run (67).fbx
# FBX version: 7700
# Proccessing file: run (68).fbx
# FBX version: 7700
# Proccessing file: run (69).fbx
# FBX version: 7700
# Proccessing file: run (7).fbx
# FBX version: 7700
# Proccessing file: run (70).fbx
# FBX version: 7700
# Proccessing file: run (71).fbx
# FBX version: 7700
# Proccessing file: run (72).fbx
# FBX version: 7700
# Proccessing file: run (73).fbx
# FBX version: 7700
# Proccessing file: run (74).fbx
# FBX version: 7700
# Proccessing file: run (75).fbx
# FBX version: 7700
# Proccessing file: run (76).fbx
# FBX version: 7700
# Proccessing file: run (77).fbx
# FBX version: 7700
# Proccessing file: run (78).fbx
# FBX version: 7700
# Proccessing file: run (79).fbx
# FBX version: 7700
# Proccessing file: run (8).fbx
# FBX version: 7700
# Proccessing file: run (80).fbx
# FBX version: 7700
# Proccessing file: run (81).fbx
# FBX version: 7700
# Proccessing file: run (82).fbx
# FBX version: 7700
# Proccessing file: run (83).fbx
# FBX version: 7700
# Proccessing file: run (84).fbx
# FBX version: 7700
# Proccessing file: run (85).fbx
# FBX version: 7700
# Proccessing file: run (86).fbx
# FBX version: 7700
# Proccessing file: run (87).fbx
# FBX version: 7700
# Proccessing file: run (88).fbx
# FBX version: 7700
# Proccessing file: run (89).fbx
# FBX version: 7700
# Proccessing file: run (9).fbx
# FBX version: 7700
# Proccessing file: run (90).fbx
# FBX version: 7700
# Proccessing file: run (91).fbx
# FBX version: 7700
# Proccessing file: run (92).fbx
# FBX version: 7700
# Proccessing file: run (93).fbx
# FBX version: 7700
# Proccessing file: run (94).fbx
# FBX version: 7700
# Proccessing file: sit (1).fbx
# FBX version: 7700
# Proccessing file: sit (10).fbx
# FBX version: 7700
# Proccessing file: sit (11).fbx
# FBX version: 7700
# Proccessing file: sit (12).fbx
# FBX version: 7700
# Proccessing file: sit (13).fbx
# FBX version: 7700
# Proccessing file: sit (14).fbx
# FBX version: 7700
# Proccessing file: sit (15).fbx
# FBX version: 7700
# Proccessing file: sit (16).fbx
# FBX version: 7700
# Proccessing file: sit (17).fbx
# FBX version: 7700
# Proccessing file: sit (18).fbx
# FBX version: 7700
# Proccessing file: sit (19).fbx
# FBX version: 7700
# Proccessing file: sit (2).fbx
# FBX version: 7700
# Proccessing file: sit (20).fbx
# FBX version: 7700
# Proccessing file: sit (21).fbx
# FBX version: 7700
# Proccessing file: sit (22).fbx
# FBX version: 7700
# Proccessing file: sit (23).fbx
# FBX version: 7700
# Proccessing file: sit (24).fbx
# FBX version: 7700
# Proccessing file: sit (25).fbx
# FBX version: 7700
# Proccessing file: sit (26).fbx
# FBX version: 7700
# Proccessing file: sit (27).fbx
# FBX version: 7700
# Proccessing file: sit (28).fbx
# FBX version: 7700
# Proccessing file: sit (29).fbx
# FBX version: 7700
# Proccessing file: sit (3).fbx
# FBX version: 7700
# Proccessing file: sit (30).fbx
# FBX version: 7700
# Proccessing file: sit (31).fbx
# FBX version: 7700
# Proccessing file: sit (32).fbx
# FBX version: 7700
# Proccessing file: sit (33).fbx
# FBX version: 7700
# Proccessing file: sit (34).fbx
# FBX version: 7700
# Proccessing file: sit (35).fbx
# FBX version: 7700
# Proccessing file: sit (36).fbx
# FBX version: 7700
# Proccessing file: sit (37).fbx
# FBX version: 7700
# Proccessing file: sit (38).fbx
# FBX version: 7700
# Proccessing file: sit (39).fbx
# FBX version: 7700
# Proccessing file: sit (4).fbx
# FBX version: 7700
# Proccessing file: sit (40).fbx
# FBX version: 7700
# Proccessing file: sit (41).fbx
# FBX version: 7700
# Proccessing file: sit (42).fbx
# FBX version: 7700
# Proccessing file: sit (43).fbx
# FBX version: 7700
# Proccessing file: sit (44).fbx
# FBX version: 7700
# Proccessing file: sit (45).fbx
# FBX version: 7700
# Proccessing file: sit (46).fbx
# FBX version: 7700
# Proccessing file: sit (47).fbx
# FBX version: 7700
# Proccessing file: sit (48).fbx
# FBX version: 7700
# Proccessing file: sit (49).fbx
# FBX version: 7700
# Proccessing file: sit (5).fbx
# FBX version: 7700
# Proccessing file: sit (50).fbx
# FBX version: 7700
# Proccessing file: sit (51).fbx
# FBX version: 7700
# Proccessing file: sit (52).fbx
# FBX version: 7700
# Proccessing file: sit (53).fbx
# FBX version: 7700
# Proccessing file: sit (54).fbx
# FBX version: 7700
# Proccessing file: sit (55).fbx
# FBX version: 7700
# Proccessing file: sit (56).fbx
# FBX version: 7700
# Proccessing file: sit (57).fbx
# FBX version: 7700
# Proccessing file: sit (58).fbx
# FBX version: 7700
# Proccessing file: sit (59).fbx
# FBX version: 7700
# Proccessing file: sit (6).fbx
# FBX version: 7700
# Proccessing file: sit (60).fbx
# FBX version: 7700
# Proccessing file: sit (61).fbx
# FBX version: 7700
# Proccessing file: sit (62).fbx
# FBX version: 7700
# Proccessing file: sit (63).fbx
# FBX version: 7700
# Proccessing file: sit (64).fbx
# FBX version: 7700
# Proccessing file: sit (65).fbx
# FBX version: 7700
# Proccessing file: sit (66).fbx
# FBX version: 7700
# Proccessing file: sit (67).fbx
# FBX version: 7700
# Proccessing file: sit (68).fbx
# FBX version: 7700
# Proccessing file: sit (69).fbx
# FBX version: 7700
# Proccessing file: sit (7).fbx
# FBX version: 7700
# Proccessing file: sit (70).fbx
# FBX version: 7700
# Proccessing file: sit (71).fbx
# FBX version: 7700
# Proccessing file: sit (72).fbx
# FBX version: 7700
# Proccessing file: sit (73).fbx
# FBX version: 7700
# Proccessing file: sit (74).fbx
# FBX version: 7700
# Proccessing file: sit (75).fbx
# FBX version: 7700
# Proccessing file: sit (76).fbx
# FBX version: 7700
# Proccessing file: sit (77).fbx
# FBX version: 7700
# Proccessing file: sit (78).fbx
# FBX version: 7700
# Proccessing file: sit (79).fbx
# FBX version: 7700
# Proccessing file: sit (8).fbx
# FBX version: 7700
# Proccessing file: sit (80).fbx
# FBX version: 7700
# Proccessing file: sit (81).fbx
# FBX version: 7700
# Proccessing file: sit (82).fbx
# FBX version: 7700
# Proccessing file: sit (83).fbx
# FBX version: 7700
# Proccessing file: sit (84).fbx
# FBX version: 7700
# Proccessing file: sit (85).fbx
# FBX version: 7700
# Proccessing file: sit (86).fbx
# FBX version: 7700
# Proccessing file: sit (87).fbx
# FBX version: 7700
# Proccessing file: sit (88).fbx
# FBX version: 7700
# Proccessing file: sit (89).fbx
# FBX version: 7700
# Proccessing file: sit (9).fbx
# FBX version: 7700

# %%
api.dataset_create_version(
    folder="./dataset",
    version_notes='Updated dataset with new data',
    convert_to_csv=False,  # Set to True if you want to convert files to CSV
    dir_mode='zip'  # Set to 'overwrite' if you want to replace existing files
)
# Out:
# Starting upload for file dance.zip
# 100%|██████████| 28.0M/28.0M [00:02<00:00, 13.8MB/s]
# Upload successful: dance.zip (28MB)
# Starting upload for file dataset_changelog.md
# 100%|██████████| 340/340 [00:00<00:00, 802B/s]
# Upload successful: dataset_changelog.md (340B)
# Starting upload for file fight.zip
# 100%|██████████| 8.32M/8.32M [00:01<00:00, 5.24MB/s]
# Upload successful: fight.zip (8MB)
# Starting upload for file greeting.zip
# 100%|██████████| 799k/799k [00:01<00:00, 745kB/s]
# Upload successful: greeting.zip (799KB)
# Starting upload for file point_out.zip
# 100%|██████████| 1.20M/1.20M [00:01<00:00, 1.04MB/s]
# Upload successful: point_out.zip (1MB)
# Starting upload for file run.zip
# 100%|██████████| 5.12M/5.12M [00:01<00:00, 3.68MB/s]
# Upload successful: run.zip (5MB)
# Starting upload for file sit.zip
# 100%|██████████| 10.7M/10.7M [00:01<00:00, 8.52MB/s]
# Upload successful: sit.zip (11MB)
# https://www.kaggle.com/alk222/raw-mixamo-animations
